# %% [markdown]
# # Barplot ile kategorik değişkenlerimizi görselleştirelim

# %%
# %run ../2_Visualization/0_Preparation.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              35 non-null     datetime64[ns]
#  1   start_time        35 non-null     object
#  2   finish_time       35 non-null     object
#  3   writer            35 non-null     object
#  4   book              35 non-null     object
#  5   kind              35 non-null     object
#  6   start_page        32 non-null     float64
#  7   finish_page       32 non-null     float64
#  8   summary_size      32 non-null     float64
#  9   is_section_liked  35 non-null     int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 2.9+ KB

# %%
# Writer'ın sınıf frekanslarına görsel olarak bakalım.

df["writer"].value_counts().plot.barh().set_title("writer Değişkeninin Sınıf Frekansları");

# %%
df["book"].value_counts().plot.barh().set_title("book Değişkeninin Sınıf Frekansları");

# %%
df["kind"].value_counts().plot.barh().set_title("kind Değişkeninin Sınıf Frekansları");

# %%
import seaborn as sns

# %%
sns.barplot(x = "book", y = "reading_time", data = df);
